# %% [markdown]
# ## Dog Breed Prediction
# source: https://www.kaggle.com/datasets/catherinehorng/dogbreedidfromcomp

# %%
# Important library imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# tqdm is a library in Python that provides a fast, extensible progress bar for
# loops and other iterable processes. When you use from tqdm import tqdm,
# you are importing the tqdm class, which you can then use to wrap an iterable
# and create a progress bar for it. This can be particularly useful when you have
# long-running tasks or loops, as it gives you a visual indication of the progres
from tqdm import tqdm
from keras.preprocessing import image
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D
from keras.optimizers import Adam
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dog_breed_path = '../input/dogbreedidfromcomp/labels.csv'

# %%
# Read the labels.csv file and checking shape and records
labels_all = pd.read_csv(dog_breed_path)
print(labels_all.shape)
labels_all.head()
# Out:
# (10222, 2)
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
len(labels_all['breed'].unique())
# Out:
# 120

# %%
# Visualize the number of each breeds
breeds_all = labels_all["breed"]
breed_counts = breeds_all.value_counts()
breed_counts
# Out:
# breed
# scottish_deerhound      126
# maltese_dog             117
# afghan_hound            116
# entlebucher             115
# bernese_mountain_dog    114
#                        ...
# golden_retriever         67
# brabancon_griffon        67
# komondor                 67
# eskimo_dog               66
# briard                   66
# Name: count, Length: 120, dtype: int64

# %% [markdown]
# Here we are finding out the count per class i.e. total data in each class using value_counts() function.

# %%
# # Selecting first 3 breeds (Limitation due to computation power)
np.random.seed(1)
CLASS_NAMES =  np.random.choice(labels_all['breed'].unique(), size=50, replace=False)
labels = labels_all[(labels_all['breed'].isin(CLASS_NAMES))]
labels = labels.reset_index()
labels
# Out:
#       index                                id                     breed
# 0         2  001cdf01b096e06d78e9e5112d419397                  pekinese
# 1        11  0067dc3eab0b3c3ef0439477624d85d6              walker_hound
# 2        19  008887054b18ba3c7601792b6a453cc3                     boxer
# 3        21  008ba178d6dfc1a583617470d19c1673                otterhound
# 4        22  009509be3ca7cce0ff9e37c8b09b1125                otterhound
# ...     ...                               ...                       ...
# 4173  10205  ffa0ad682c6670db3defce2575a2587f          english_springer
# 4174  10214  ffcb610e811817766085054616551f9c                    briard
# 4175  10216  ffcffab7e4beef9a9b8076ef2ca51909                   samoyed
# 4176  10220  ffe5f6d8e2bff356e9482a80a6e29aac        miniature_pinscher
# 4177  10221  fff43b07992508bc822f33d8ffd902ae  chesapeake_bay_retriever
#
# [4178 rows x 3 columns]

# %%
labels['breed'].unique()
# Out:
# array(['pekinese', 'walker_hound', 'boxer', 'otterhound',
#        'english_setter', 'dhole', 'toy_poodle', 'border_terrier',
#        'norwegian_elkhound', 'shih-tzu', 'kuvasz', 'german_shepherd',
#        'greater_swiss_mountain_dog', 'australian_terrier',
#        'rhodesian_ridgeback', 'appenzeller', 'samoyed', 'border_collie',
#        'entlebucher', 'collie', 'malamute', 'chihuahua', 'saluki',
#        'komondor', 'bull_mastiff', 'bernese_mountain_dog', 'lhasa',
#        'scotch_terrier', 'miniature_pinscher', 'brabancon_griffon',
#        'toy_terrier', 'flat-coated_retriever',
#        'soft-coated_wheaten_terrier', 'siberian_husky', 'briard',
#        'chesapeake_bay_retriever', 'beagle', 'vizsla',
#        'west_highland_white_terrier', 'kerry_blue_terrier', 'whippet',
#        'japanese_spaniel', 'curly-coated_retriever', 'pembroke',
#        'silky_terrier', 'sussex_spaniel', 'german_short-haired_pointer',
#        'french_bulldog', 'english_springer', 'rottweiler'], dtype=object)

# %%
len(labels['breed'].unique())
# Out:
# 50

# %%
len(CLASS_NAMES)
# Out:
# 50

# %%
# Creating numpy matrix with zeros
X_data = np.zeros((len(labels), 224, 224, 3), dtype='float32')
# One hot encoding
Y_data = label_binarize(labels['breed'], classes = CLASS_NAMES)

# Reading and converting image to numpy array and normalizing dataset
for i in tqdm(range(len(labels))):

    # target_size=(224, 224): resizes the image to a standard size of 224x224 pixels.
    # %s for keep 'labels['id'][i]' as string format
    # For example  labels['id'][i] holds the value '00123', the resulting path becomes:
    #         'dog_dataset/train/00123.jpg'
    img = image.load_img('../input/dogbreedidfromcomp/train/%s.jpg' % labels['id'][i], target_size=(224, 224))
    img = image.img_to_array(img)

    x = np.expand_dims(img.copy(), axis=0)
    # Normalizing pixel values  to avoid the possibility of exploding gradients
    # because of the high range of the pixels [0, 255], and improve the convergence speed.
    X_data[i] = x / 255.0

# Printing train image and one hot encode shape & size
print('\nTrain Images shape: ',X_data.shape,' size: {:,}'.format(X_data.size))
print('One-hot encoded output shape: ',Y_data.shape,' size: {:,}'.format(Y_data.size))
# Out:
# 100%|██████████| 4178/4178 [00:36<00:00, 115.23it/s]
# Train Images shape:  (4178, 224, 224, 3)  size: 628,905,984
# One-hot encoded output shape:  (4178, 50)  size: 208,900

# %%
Y_data = label_binarize(labels['breed'], classes = list(labels['breed'].unique()))
print('One-hot encoded output shape: ',Y_data.shape,' size: {:,}'.format(Y_data.size))
# Out:
# One-hot encoded output shape:  (4178, 50)  size: 208,900

# %%
# Splitting the data set into training and testing data sets
X_train_and_val, X_test, Y_train_and_val, Y_test = train_test_split(X_data, Y_data, test_size = 0.1)
# Splitting the training data set into training and validation data sets
X_train, X_val, Y_train, Y_val = train_test_split(X_train_and_val, Y_train_and_val, test_size = 0.2)

# %% [markdown]
# From normal architech of convolutional neuron network (CNNs) will chance to vanishing and exploding gradient problem (When add #layer until certain point. The performance will increasing then after certain point will going to decrease the performance) when CNNs get more deeper. So I will try to use MobileNetV2 Architecture for reduce that problem.

# %%
from keras.applications import MobileNetV2
from keras import Sequential
from keras.layers import Dense, Flatten
from keras.optimizers import Adam

# Load pre-trained MobileNetV2 model
# include_top: whether to include the 3 fully-connected layers at the top of the network.
base_model = MobileNetV2(
    weights='imagenet',
    include_top=True,
    input_shape=(224, 224, 3),
    pooling='max',
    classifier_activation="softmax"
)

# Freeze the convolutional layers
for layer in base_model.layers:
    layer.trainable = False

# Create a new model on top of the MobileNetV2 base
model = Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dense(724, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(Y_data.shape[1], activation='softmax'))  # Adjust the number of classes based on your dataset

# Compile the model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224.h5
# 14536120/14536120 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenetv2_1.00_224 (Func  (None, 1000)              3538984
#  tional)
#
#  flatten (Flatten)           (None, 1000)              0
#
#  dense (Dense)               (None, 724)               724724
#
#  dense_1 (Dense)             (None, 512)               371200
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 50)                3250
#
# =================================================================
# Total params: 4876430 (18.60 MB)
# Trainable params: 1337446 (5.10 MB)
# Non-trainable params: 3538984 (13.50 MB)
# _________________________________________________________________

# %%
# Training the model
epochs = 70
batch_size = 192

history = model.fit(X_train, Y_train, batch_size = batch_size, epochs = epochs,
                    validation_data = (X_val, Y_val))
# Out:
# Epoch 1/70
# 16/16 [==============================] - 14s 438ms/step - loss: 3.9068 - accuracy: 0.0662 - val_loss: 3.8996 - val_accuracy: 0.1184
# Epoch 2/70
# 16/16 [==============================] - 3s 210ms/step - loss: 3.8911 - accuracy: 0.1712 - val_loss: 3.8785 - val_accuracy: 0.1662
# Epoch 3/70
# 16/16 [==============================] - 3s 207ms/step - loss: 3.8619 - accuracy: 0.1809 - val_loss: 3.8359 - val_accuracy: 0.1622
# Epoch 4/70
# 16/16 [==============================] - 3s 208ms/step - loss: 3.8025 - accuracy: 0.2011 - val_loss: 3.7508 - val_accuracy: 0.2101
# Epoch 5/70
# 16/16 [==============================] - 3s 208ms/step - loss: 3.6863 - accuracy: 0.2450 - val_loss: 3.5907 - val_accuracy: 0.2487
# Epoch 6/70
# 16/16 [==============================] - 3s 208ms/step - loss: 3.4733 - accuracy: 0.3012 - val_loss: 3.3141 - val_accuracy: 0.3152
# Epoch 7/70
# 16/16 [==============================] - 3s 207ms/step - loss: 3.1349 - accuracy: 0.3720 - val_loss: 2.9019 - val_accuracy: 0.4255
# Epoch 8/70
# 16/16 [==============================] - 3s 208ms/step - loss: 2.6749 - accuracy: 0.4794 - val_loss: 2.3977 - val_accuracy: 0.5652
# Epoch 9/70
# 16/16 [==============================] - 3s 208ms/step - loss: 2.1673 - accuracy: 0.6031 - val_loss: 1.9067 - val_accuracy: 0.6742
# Epoch 10/70
# 16/16 [==============================] - 3s 209ms/step - loss: 1.7173 - accuracy: 0.6995 - val_loss: 1.5120 - val_accuracy: 0.7447
# Epoch 11/70
# 16/16 [==============================] - 3s 208ms/step - loss: 1.3851 - accuracy: 0.7573 - val_loss: 1.2527 - val_accuracy: 0.7846
# Epoch 12/70
# 16/16 [==============================] - 3s 210ms/step - loss: 1.1688 - accuracy: 0.7916 - val_loss: 1.0821 - val_accuracy: 0.7779
# Epoch 13/70
# 16/16 [==============================] - 3s 209ms/step - loss: 1.0340 - accuracy: 0.8025 - val_loss: 0.9824 - val_accuracy: 0.8019
# Epoch 14/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.9480 - accuracy: 0.8155 - val_loss: 0.9226 - val_accuracy: 0.7992
# Epoch 15/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.8814 - accuracy: 0.8205 - val_loss: 0.8853 - val_accuracy: 0.8019
# Epoch 16/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.8412 - accuracy: 0.8258 - val_loss: 0.8619 - val_accuracy: 0.8072
# Epoch 17/70
# 16/16 [==============================] - 3s 207ms/step - loss: 0.8024 - accuracy: 0.8348 - val_loss: 0.8312 - val_accuracy: 0.8085
# Epoch 18/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.7714 - accuracy: 0.8404 - val_loss: 0.8136 - val_accuracy: 0.8059
# Epoch 19/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.7528 - accuracy: 0.8404 - val_loss: 0.8102 - val_accuracy: 0.8112
# Epoch 20/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.7257 - accuracy: 0.8441 - val_loss: 0.8082 - val_accuracy: 0.8045
# Epoch 21/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.7146 - accuracy: 0.8467 - val_loss: 0.7969 - val_accuracy: 0.8098
# Epoch 22/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.6918 - accuracy: 0.8461 - val_loss: 0.7675 - val_accuracy: 0.8138
# Epoch 23/70
# 16/16 [==============================] - 3s 207ms/step - loss: 0.6713 - accuracy: 0.8534 - val_loss: 0.7664 - val_accuracy: 0.8178
# Epoch 24/70
# 16/16 [==============================] - 3s 207ms/step - loss: 0.6547 - accuracy: 0.8524 - val_loss: 0.7850 - val_accuracy: 0.8045
# Epoch 25/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.6421 - accuracy: 0.8554 - val_loss: 0.7662 - val_accuracy: 0.8072
# Epoch 26/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.6347 - accuracy: 0.8567 - val_loss: 0.7547 - val_accuracy: 0.8165
# Epoch 27/70
# 16/16 [==============================] - 3s 207ms/step - loss: 0.6222 - accuracy: 0.8544 - val_loss: 0.7443 - val_accuracy: 0.8125
# Epoch 28/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.6032 - accuracy: 0.8574 - val_loss: 0.7508 - val_accuracy: 0.8218
# Epoch 29/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.5870 - accuracy: 0.8634 - val_loss: 0.7362 - val_accuracy: 0.8191
# Epoch 30/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.5710 - accuracy: 0.8667 - val_loss: 0.7300 - val_accuracy: 0.8165
# Epoch 31/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.5642 - accuracy: 0.8667 - val_loss: 0.7235 - val_accuracy: 0.8205
# Epoch 32/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.5507 - accuracy: 0.8674 - val_loss: 0.7231 - val_accuracy: 0.8191
# Epoch 33/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.5423 - accuracy: 0.8674 - val_loss: 0.7201 - val_accuracy: 0.8231
# Epoch 34/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.5338 - accuracy: 0.8670 - val_loss: 0.7228 - val_accuracy: 0.8125
# Epoch 35/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.5259 - accuracy: 0.8690 - val_loss: 0.7278 - val_accuracy: 0.8191
# Epoch 36/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.5166 - accuracy: 0.8727 - val_loss: 0.7245 - val_accuracy: 0.8191
# Epoch 37/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.5086 - accuracy: 0.8727 - val_loss: 0.7162 - val_accuracy: 0.8245
# Epoch 38/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.4985 - accuracy: 0.8747 - val_loss: 0.7144 - val_accuracy: 0.8178
# Epoch 39/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.4927 - accuracy: 0.8733 - val_loss: 0.7171 - val_accuracy: 0.8152
# Epoch 40/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.4785 - accuracy: 0.8793 - val_loss: 0.7180 - val_accuracy: 0.8165
# Epoch 41/70
# 16/16 [==============================] - 3s 212ms/step - loss: 0.4703 - accuracy: 0.8767 - val_loss: 0.7169 - val_accuracy: 0.8218
# Epoch 42/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.4692 - accuracy: 0.8783 - val_loss: 0.7138 - val_accuracy: 0.8245
# Epoch 43/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.4629 - accuracy: 0.8800 - val_loss: 0.7128 - val_accuracy: 0.8218
# Epoch 44/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.4549 - accuracy: 0.8793 - val_loss: 0.7178 - val_accuracy: 0.8152
# Epoch 45/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.4524 - accuracy: 0.8813 - val_loss: 0.7207 - val_accuracy: 0.8191
# Epoch 46/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.4583 - accuracy: 0.8740 - val_loss: 0.7347 - val_accuracy: 0.8178
# Epoch 47/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.4438 - accuracy: 0.8793 - val_loss: 0.7422 - val_accuracy: 0.8152
# Epoch 48/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.4335 - accuracy: 0.8853 - val_loss: 0.7143 - val_accuracy: 0.8165
# Epoch 49/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.4250 - accuracy: 0.8833 - val_loss: 0.7250 - val_accuracy: 0.8205
# Epoch 50/70
# 16/16 [==============================] - 3s 211ms/step - loss: 0.4153 - accuracy: 0.8863 - val_loss: 0.7105 - val_accuracy: 0.8258
# Epoch 51/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.4123 - accuracy: 0.8840 - val_loss: 0.7279 - val_accuracy: 0.8258
# Epoch 52/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.4029 - accuracy: 0.8910 - val_loss: 0.7131 - val_accuracy: 0.8218
# Epoch 53/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.3956 - accuracy: 0.8903 - val_loss: 0.7332 - val_accuracy: 0.8112
# Epoch 54/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.3906 - accuracy: 0.8933 - val_loss: 0.7149 - val_accuracy: 0.8245
# Epoch 55/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.3898 - accuracy: 0.8903 - val_loss: 0.7109 - val_accuracy: 0.8258
# Epoch 56/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.3829 - accuracy: 0.8926 - val_loss: 0.7227 - val_accuracy: 0.8205
# Epoch 57/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.3767 - accuracy: 0.8949 - val_loss: 0.7227 - val_accuracy: 0.8271
# Epoch 58/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.3714 - accuracy: 0.8933 - val_loss: 0.7249 - val_accuracy: 0.8138
# Epoch 59/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.3711 - accuracy: 0.8949 - val_loss: 0.7199 - val_accuracy: 0.8285
# Epoch 60/70
# 16/16 [==============================] - 3s 211ms/step - loss: 0.3695 - accuracy: 0.8930 - val_loss: 0.7385 - val_accuracy: 0.8165
# Epoch 61/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.3641 - accuracy: 0.8966 - val_loss: 0.7398 - val_accuracy: 0.8205
# Epoch 62/70
# 16/16 [==============================] - 3s 215ms/step - loss: 0.3604 - accuracy: 0.8976 - val_loss: 0.7392 - val_accuracy: 0.8245
# Epoch 63/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.3540 - accuracy: 0.8983 - val_loss: 0.7513 - val_accuracy: 0.8178
# Epoch 64/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.3519 - accuracy: 0.8979 - val_loss: 0.7427 - val_accuracy: 0.8178
# Epoch 65/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.3468 - accuracy: 0.8986 - val_loss: 0.7583 - val_accuracy: 0.8138
# Epoch 66/70
# 16/16 [==============================] - 3s 208ms/step - loss: 0.3418 - accuracy: 0.9019 - val_loss: 0.7417 - val_accuracy: 0.8218
# Epoch 67/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.3430 - accuracy: 0.9049 - val_loss: 0.7486 - val_accuracy: 0.8165
# Epoch 68/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.3364 - accuracy: 0.9013 - val_loss: 0.7513 - val_accuracy: 0.8191
# Epoch 69/70
# 16/16 [==============================] - 3s 209ms/step - loss: 0.3337 - accuracy: 0.9029 - val_loss: 0.7591 - val_accuracy: 0.8165
# Epoch 70/70
# 16/16 [==============================] - 3s 210ms/step - loss: 0.3260 - accuracy: 0.9043 - val_loss: 0.7567 - val_accuracy: 0.8165

# %%
# Plot the training history
plt.figure(figsize=(6, 3))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
# Plot the training history
plt.figure(figsize=(6, 3))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
Y_pred = model.predict(X_test)
score = model.evaluate(X_test, Y_test)
print('Accuracy over the test set: \n ', round((score[1]*100), 2), '%')
# Out:
# 14/14 [==============================] - 2s 46ms/step
# 14/14 [==============================] - 0s 30ms/step - loss: 0.9215 - accuracy: 0.8086
# Accuracy over the test set:
#   80.86 %

# %%
# Plotting image to compare
plt.imshow(X_test[1,:,:,:])
plt.show()

# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",labels['breed'][np.argmax(Y_test[1])])
print("Predicted : ",labels['breed'][np.argmax(Y_pred[1])])
# Out:
# Originally :  dhole
# Predicted :  dhole

# %% [markdown]
# ### Save model

# %%
model.save('dog_breed.h5')
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
